# %%
import os
os.environ["OMP_NUM_THREADS"] = "6"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
two_blobs = pd.read_csv('../DATA/cluster_two_blobs.csv')

# %%
two_blobs_outliers = pd.read_csv('../DATA/cluster_two_blobs_outliers.csv')

# %%
sns.scatterplot(data=two_blobs_outliers,x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
def display_categories(model,data):
    labels = model.fit_predict(data)
    sns.scatterplot(data = data,x='X1',y='X2',hue=labels,palette='Set1')

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN()

# %%
display_categories(dbscan,two_blobs)

# %%
display_categories(dbscan,two_blobs_outliers)

# %%
dbscan = DBSCAN(eps=1)
display_categories(dbscan,two_blobs_outliers)

# %%
# Total Outliers Found
np.sum(dbscan.labels_  == -1)
# Out:
# np.int64(3)

# %%
# percent of points classified as outliers
100 * np.sum(dbscan.labels_  == -1) / len(dbscan.labels_)
# Out:
# np.float64(0.29910269192422734)

# %%
len(dbscan.labels_)
# Out:
# 1003

# %%
outlier_percent = []
number_of_ouliers = []

for n in np.arange(1,100):

    dbscan = DBSCAN(min_samples=n)
    dbscan.fit(two_blobs_outliers)

    # Total Outliers Found
    number_of_ouliers.append(np.sum(dbscan.labels_  == -1))

    # percent of points classified as outliers
    perc_outliers = 100 * np.sum(dbscan.labels_  == -1) / len(dbscan.labels_)

    outlier_percent.append(perc_outliers)

# %%
# sns.lineplot(x=np.linspace(0.001,1,100),y=number_of_ouliers)
# plt.xlim(0,2)
# plt.ylim(0,10)
# plt.hlines(y=3,xmin=0,xmax=2,colors='red')

# %%
# sns.lineplot(x=np.linspace(0.001,1,100),y=outlier_percent)
# plt.hlines(y=1,xmin=0,xmax=2,colors='red')
# plt.ylim(0,10)

# plt.xlim(0,2)

# %%
sns.lineplot(x=np.arange(1,100),y=outlier_percent)
plt.xlabel('Min Number of Sample')
plt.ylabel('pct. of points classified as an outlier')
# Out:
# Text(0, 0.5, 'pct. of points classified as an outlier')

# %%
min_dim = two_blobs_outliers.shape[1]
DBSCAN(min_samples=2*min_dim,eps=0.75)
display_categories(dbscan,two_blobs_outliers)

# %%
two_blobs_outliers.shape
# Out:
# (1003, 2)
